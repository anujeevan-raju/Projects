# %% [markdown]
# ### Importing Libraries

# %%
#importing the libraries
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Data Preparation and Data Exploration

# %%
marvel_heros = pd.read_csv('F:/Desktop/Pyton Project/marvel_heros.csv')

# %%
marvel_heros
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 0            3-D Man      good            50        31     43          32
# 1             A-Bomb      good            38       100     17          80
# 2         Abe Sapien      good            88        14     35          42
# 3           Abin Sur      good            50        90     53          64
# 4        Abomination       bad            63        80     53          90
# ..               ...       ...           ...       ...    ...         ...
# 606     Yellowjacket      good            88        10     12          28
# 607  Yellowjacket II      good            50        10     35          28
# 608             Ymir      good            50       100     27         100
# 609          Zatanna      good            75        10     23          28
# 610             Zoom       bad            50        10    100          28
#
#      Power  Combat  Total
# 0       25      52    233
# ...

# %% [markdown]
# ### Sneak Peak and Explore Data

# %%
marvel_heros.head()
# Out:
#           Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0      3-D Man      good            50        31     43          32     25
# 1       A-Bomb      good            38       100     17          80     17
# 2   Abe Sapien      good            88        14     35          42     35
# 3     Abin Sur      good            50        90     53          64     84
# 4  Abomination       bad            63        80     53          90     55
#
#    Combat  Total
# 0      52    233
# 1      64    316
# 2      85    299
# 3      65    406
# 4      95    436

# %%
marvel_heros.shape
# Out:
# (611, 9)

# %% [markdown]
# ### Descriptive Statistics

# %%
marvel_heros.describe()
# Out:
#        Intelligence    Strength       Speed  Durability       Power  \
# count    611.000000  611.000000  611.000000  611.000000  611.000000
# mean      44.502455   29.083470   27.306056   41.839607   40.312602
# std       32.924722   32.610939   25.760173   36.543849   34.539910
# min        1.000000    1.000000    1.000000    1.000000    0.000000
# 25%        1.000000    1.000000    1.000000    1.000000    0.000000
# 50%       50.000000   10.000000   23.000000   32.000000   37.000000
# 75%       75.000000   53.000000   42.000000   80.000000   67.000000
# max      113.000000  100.000000  100.000000  120.000000  100.000000
#
#            Combat       Total
# count  611.000000  611.000000
# mean    43.206219  226.250409
# std     33.270329  167.324034
# min      1.000000    5.000000
# 25%      1.000000    5.000000
# 50%     50.000000  255.000000
# 75%     70.000000  351.500000
# max    101.000000  581.000000

# %%
#lets check how many are good and bad heros
marvel_heros['Alignment'].value_counts()
# Out:
# Alignment
# good       432
# bad        165
# neutral     11
# Name: count, dtype: int64

# %%
# lets check the good ones
good_heros = marvel_heros[marvel_heros['Alignment'] == 'good']

# %%
good_heros
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 0            3-D Man      good            50        31     43          32
# 1             A-Bomb      good            38       100     17          80
# 2         Abe Sapien      good            88        14     35          42
# 3           Abin Sur      good            50        90     53          64
# 6        Adam Monroe      good            63        10     12         100
# ..               ...       ...           ...       ...    ...         ...
# 604            X-Man      good            88        53     53          95
# 606     Yellowjacket      good            88        10     12          28
# 607  Yellowjacket II      good            50        10     35          28
# 608             Ymir      good            50       100     27         100
# 609          Zatanna      good            75        10     23          28
#
#      Power  Combat  Total
# 0       25      52    233
# ...

# %%
# let's check the intelligence, speed, power and strength of the heros
qualities_heros = marvel_heros[['Name','Intelligence','Strength','Speed','Power']]

# %%
qualities_heros.head()
# Out:
#           Name  Intelligence  Strength  Speed  Power
# 0      3-D Man            50        31     43     25
# 1       A-Bomb            38       100     17     17
# 2   Abe Sapien            88        14     35     35
# 3     Abin Sur            50        90     53     84
# 4  Abomination            63        80     53     55

# %%
#lets check who has highest intelligence in more strength, speed and power 
#on good heros side
intel_good_hero = marvel_heros[marvel_heros['Alignment'] == 'good'].sort_values(by=['Intelligence','Strength','Speed','Power'], 
                                                                                ascending = [False,False,False,False]).head()

# %%
intel_good_hero
# Out:
#                   Name Alignment  Intelligence  Strength  Speed  Durability  \
# 537           Superman      good           100       100    100         100
# 361  Martian Manhunter      good           100       100     96         100
# 138     Captain Marvel      good           100       100     67          95
# 417               Nova      good           100        85     67         101
# 299           Iron Man      good           100        85     58          85
#
#      Power  Combat  Total
# 537     94      85    579
# 361    100      85    581
# 138     62      56    480
# 417    100      85    538
# 299    100      64    492

# %% [markdown]
# Superman comes first from the good heros, and
# Martian Manhunter comes second

# %%
#lets check who has highest intelligence in more strength, speed and power 
#on bad heros side
intel_bad_hero = marvel_heros[marvel_heros['Alignment'] == 'bad'].sort_values(by=['Intelligence','Strength','Speed','Power'], 
                                                                              ascending = [False,False,False,False]).head()

# %%
intel_bad_hero
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 386  Mister Mxyzptlk       bad           113        10     12          14
# 29        Apocalypse       bad           100       100     33         100
# 321             Kang       bad           100        48     58          70
# 194      Doctor Doom       bad           100        32     20         100
# 122         Brainiac       bad           100        28     63          90
#
#      Power  Combat  Total
# 386    100      28    277
# 29     100      60    493
# 321     71      70    417
# 194     93      84    429
# 122     60      75    416

# %% [markdown]
# Mister Mxyzptlk comes firstfrom the bad heros with intelligence of *113* and Apocalypse comes second

# %%
good = marvel_heros[marvel_heros['Alignment'] == 'good']

# %%
good_max_power = good.sort_values(by=['Total'], ascending = False).head()

# %%
good_max_power
# Out:
#                   Name Alignment  Intelligence  Strength  Speed  Durability  \
# 361  Martian Manhunter      good           100       100     96         100
# 537           Superman      good           100       100    100         100
# 525           Stardust      good            88        85    100         110
# 546               Thor      good            69       100     92         100
# 536          Supergirl      good            94        98     92         100
#
#      Power  Combat  Total
# 361    100      85    581
# 537     94      85    579
# 525    100      85    568
# 546    100      85    546
# 536     85      75    544

# %% [markdown]
# When it comes to overall_good_power Martin Manhunter comes first with total of *581* and Superman comes second with total of *579*

# %%
good_min_power = good.sort_values(by=['Total'], ascending = True).head()

# %%
good_min_power
# Out:
#              Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 381  Minna Murray      good             1         1      1           1      0
# 512       Spectre      good             1         1      1           1      0
# 148       Cerebra      good             1         1      1           1      0
# 158          Clea      good             1         1      1           1      0
# 161  Colin Wagner      good             1         1      1           1      0
#
#      Combat  Total
# 381       1      5
# 512       1      5
# 148       1      5
# 158       1      5
# 161       1      5

# %% [markdown]
# Minna Murray comes with min power with total of *5* and Spectre comes second with same power as murray

# %%
bad = marvel_heros[marvel_heros['Alignment'] == 'bad']

# %%
bad_max_power = bad.sort_values(by=['Total'], ascending = False).head()

# %%
bad_max_power
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 535  Superboy-Prime       bad            94       100    100         100
# 242     General Zod       bad            94       100     96         100
# 16            Amazo       bad            75       100    100         100
# 203        Dormammu       bad            88        95     83         100
# 201        Doomsday       bad            88        80     67         120
#
#      Power  Combat  Total
# 535    100      85    579
# 242     94      95    579
# 16     100     100    575
# 203    100      80    546
# 201    100      90    545

# %% [markdown]
# When it comes with overall_bad_power Superboy-Prime and General Zod comes with total of *579* and Amazo comes second with total of *575*

# %%
bad_min_power = bad.sort_values(by=['Total'], ascending = True).head()

# %%
bad_min_power
# Out:
#               Name Alignment  Intelligence  Strength  Speed  Durability  \
# 349  Luke Campbell       bad             1         1      1           1
# 115     Bomb Queen       bad             1         1      1           1
# 216  Fabian Cortez       bad             1         1      1           1
# 390         Moloch       bad             1         1      1           1
# 309         Jigsaw       bad             1         1      1           1
#
#      Power  Combat  Total
# 349      0       1      5
# 115      0       1      5
# 216      0       1      5
# 390      0       1      5
# 309      0       1      5

# %% [markdown]
# When it comes to minimum total_power Luke Campbell and Bomb Queen with total of *5*

# %%
good_max_power_total = good[good['Power'] == 100].head()

# %%
good_max_power_total
# Out:
#               Name Alignment  Intelligence  Strength  Speed  Durability  \
# 69   Beta Ray Bill      good            63        80     35          95
# 70        Beyonder      good            88       100     23         100
# 85      Black Bolt      good            75        67    100          84
# 129          Cable      good            88        48     23          56
# 185        Deadman      good            50        10     33         100
#
#      Power  Combat  Total
# 69     100      84    457
# 70     100      56    467
# 85     100      56    482
# 129    100      80    395
# 185    100      42    335

# %% [markdown]
# ### Data Visualization

# %%
# Fill missing values in 'Alignment' with 'unknown'
filtered_heros = marvel_heros[marvel_heros['Alignment'] != 'unknown']
sns.set_theme(style="darkgrid")
plt.figure(figsize=(6, 4))
sns.countplot(x="Alignment",data = filtered_heros, hue = "Alignment", palette="pastel", legend = False)
plt.title("Distribution of Alignment")
plt.xlabel("Alignment")
plt.ylabel("Count")
plt.show()

# %%
#Making a Bar plot for Maximum Power over Total for GOOD_Heros
plt.figure(figsize = (8,5))
sns.set_theme(style="darkgrid")
plt.bar(list(good_max_power['Name']),list(good_max_power['Total']),color = "b", label = 'Total_power')
plt.title('Maximum Power with Total',fontsize = 16, fontweight = "bold")
plt.xlabel('Name')
plt.ylabel('Total')
plt.legend(loc='upper left', fontsize=10, title='Group Legend',bbox_to_anchor=(1, 1))
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set theme and figure size
sns.set_theme(style="darkgrid")
plt.figure(figsize=(8, 5))

# Create bar plot using Seaborn
ax = sns.barplot(x=good_max_power['Name'][0:5], 
                 y=good_max_power['Total'][0:5], 
                 color="b", 
                 label='Total_power')

# Customize the plot
plt.title('Maximum Power with Total', fontsize=16, fontweight="bold")
plt.xlabel('Name')
plt.ylabel('Total')

# Add legend with custom position
plt.legend(loc='upper left', fontsize=10, title='Group Legend', bbox_to_anchor=(1, 1))

# Show the plot
plt.show()

# %%
#Making a Bar plot for Maximum Power over Total for BAD_Heros
plt.figure(figsize = (8,5))
sns.set_theme(style="darkgrid")
plt.bar(list(bad_max_power['Name'])[0:5],list(bad_max_power['Total'])[0:5],color = "r", label = 'Total_power')
plt.title('Maximum Power with Total',fontsize = 16, fontweight = "bold")
plt.xlabel('Name')
plt.ylabel('Total')
plt.legend(loc='upper left', fontsize=10, title='Group Legend',bbox_to_anchor=(1, 1))
plt.show()

# %%
# Distribution of total power levels
plt.figure(figsize=(8, 5))
sns.histplot(marvel_heros["Total"], bins=20, kde=True, color="purple")
plt.title("Distribution of Total Power Levels")
plt.xlabel("Total Power Level")
plt.ylabel("Count")
plt.show()

# %%
#Making a histogram fro speed for good superheroes
plt.figure(figsize=(5,5))
sns.set_theme(style="darkgrid")
plt.hist(good['Speed'],label = 'Speed')
plt.title('Distribution of Speed', fontsize = 10)
plt.xlabel('speed')
plt.legend()
plt.show()

# %%
# Making a histogram for combat fro Good_Heros
plt.figure(figsize = (5,5))
sns.set_theme(style="darkgrid")
plt.hist(good['Combat'], label = 'Combat')
plt.title('Distribution of Combat', fontsize = 10)
plt.xlabel('Combat')
plt.show()

# %%
# Correlation heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(marvel_heros.iloc[:, 2:].corr(), annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap of Attributes")
plt.show()

# %%
# Top 10 strongest superheroes
top_strongest = good.nlargest(10, "Strength")

plt.figure(figsize=(10, 5))
sns.barplot(x=top_strongest["Strength"], y=top_strongest["Name"], palette = "Reds_r")
plt.title("Top 10 Strongest Superheroes")
plt.xlabel("Strength")
plt.ylabel("Superhero")
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_11944\1532779424.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_strongest["Strength"], y=top_strongest["Name"], palette = "Reds_r")

# %%
# Boxplot of Intelligence by Alignment
filtered_heros = marvel_heros[marvel_heros['Alignment'] != 'unknown']

plt.figure(figsize=(8, 5))
sns.boxplot(x=filtered_heros["Alignment"], y=filtered_heros["Intelligence"], palette="coolwarm")
plt.title("Distribution of Intelligence by Alignment")
plt.xlabel("Alignment")
plt.ylabel("Intelligence")
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_11944\436464897.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=filtered_heros["Alignment"], y=filtered_heros["Intelligence"], palette="coolwarm")
